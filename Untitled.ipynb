# %%
import xarray as xr
import os
import numpy as np

# %%
# filepath = 'C:\\data\\RISC\\BODCREQ-4767\\NetCDF'
filepath = 'C:\\data\\RISC\\JC090\\NetCDF'
# filename = '20130601-090000-position-Applanix_GPS_JC1.gps'
# filename = '20130601-090000-position-DPS-116_JC1.gps'
# filename = '20130601-090000-gyro-GYRO1_JC1.gyr'
# filename = '20130601-090000-gyro-SGYRO_JC1.gyr'
filename='20130902-090000-satelliteinfo-Applanix_GPS_JC1.gps'
fullpath = os.path.join(filepath, filename)
fullpath
# Out:
# 'C:\\data\\RISC\\JC090\\NetCDF\\20130902-090000-satelliteinfo-Applanix_GPS_JC1.gps'

# %%
data = xr.open_dataset(fullpath)
np.timedelta64(data.time[1].data-data.time[0].data,'ms')
# Out:
# C:\Users\dmca\AppData\Local\anaconda3\envs\seastar\lib\site-packages\xarray\conventions.py:523: SerializationWarning: variable 'nbseen' has multiple fill values {-1, 255.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# C:\Users\dmca\AppData\Local\anaconda3\envs\seastar\lib\site-packages\xarray\conventions.py:523: SerializationWarning: variable 'nbused' has multiple fill values {-1, 255.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# numpy.timedelta64(998,'ms')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 86399)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-09-02T09:00:00.965087744 ... 2013-09-...
# Data variables:
#     nbseen   (time) float32 ...
#     nbused   (time) float32 ...
#     HDOP     (time) float32 ...
#     VDOP     (time) float32 ...
#     PDOP     (time) float32 ...
# Attributes: (12/24)
#     history:                       TECHSAS v.2.35 - 2006-09-23T02:56:27 UTC 2...
#     source:                        Acquisition of Applanix_GPS_JC1
#     conventions:                   CF-1.0.
#     creationtime:                  2013-09-02T09:00:00Z
#     device_firstusedate:           2000-01-01T00:00:00Z
#     device_deviceid:               Applanix_GPS_JC1
#     ...                            ...
#     frame_minor:                   0
#     frame_sourcetype:              gps
#     frame_period:                  1.0
#     title:                         Techsas 2.35
#     institution:                   Ifremer
# ...

# %%
data.heading[0:300].plot()
